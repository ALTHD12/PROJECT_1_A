# %% [markdown]
# <a href="https://colab.research.google.com/github/ALTHD12/PROJECT_1_A/blob/main/Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import seaborn as sns

# %%
digits = load_digits()
X = digits.data
y = digits.target

print(f"Data shape: {X.shape}")

X_scaled = StandardScaler().fit_transform(X)

pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)

tsne = TSNE(n_components=2, perplexity=30, learning_rate='auto', init='pca', random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

fig, axes = plt.subplots(1, 2, figsize=(16, 7))
fig.suptitle('Dimensionality Reduction Comparison: PCA vs. t-SNE', fontsize=16)

# PCA Plot
sns.scatterplot(
    x=X_pca[:, 0],
    y=X_pca[:, 1],
    hue=y,
    palette=sns.color_palette("hls", 10),
    legend="full",
    alpha=0.8,
    ax=axes[0]
)
axes[0].set_title('PCA of Digits Dataset')
axes[0].set_xlabel('Principal Component 1')
axes[0].set_ylabel('Principal Component 2')

# t-SNE Plot
sns.scatterplot(
    x=X_tsne[:, 0],
    y=X_tsne[:, 1],
    hue=y,
    palette=sns.color_palette("hls", 10),
    legend="full",
    alpha=0.8,
    ax=axes[1]
)
axes[1].set_title('t-SNE of Digits Dataset')
axes[1].set_xlabel('t-SNE Component 1')
axes[1].set_ylabel('t-SNE Component 2')


plt.show()
# Out:
# Data shape: (1797, 64)
